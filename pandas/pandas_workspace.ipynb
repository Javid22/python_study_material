# %%
import pandas as pd

# pd.read_csv("data.tsv.txt", sep="\t")
details = pd.read_table("data.tsv.txt")
print(details.head())
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# FOR Attributes no nooed to put ()
# function has ()

# %% [markdown]
# Terminology Alert
# Rows - Observations/Record
# Columns - Features/Parameter

# %%
details.shape
# Out:
# (4622, 5)

# %%
details.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
details.describe(include="all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# 4.2  Find out item sold in restaurent

# %%
details.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
print(details['item_name'].unique())
# Out:
# ['Chips and Fresh Tomato Salsa' 'Izze' 'Nantucket Nectar'
#  'Chips and Tomatillo-Green Chili Salsa' 'Chicken Bowl' 'Side of Chips'
#  'Steak Burrito' 'Steak Soft Tacos' 'Chips and Guacamole'
#  'Chicken Crispy Tacos' 'Chicken Soft Tacos' 'Chicken Burrito'
#  'Canned Soda' 'Barbacoa Burrito' 'Carnitas Burrito' 'Carnitas Bowl'
#  'Bottled Water' 'Chips and Tomatillo Green Chili Salsa' 'Barbacoa Bowl'
#  'Chips' 'Chicken Salad Bowl' 'Steak Bowl' 'Barbacoa Soft Tacos'
#  'Veggie Burrito' 'Veggie Bowl' 'Steak Crispy Tacos'
#  'Chips and Tomatillo Red Chili Salsa' 'Barbacoa Crispy Tacos'
#  'Veggie Salad Bowl' 'Chips and Roasted Chili-Corn Salsa'
#  'Chips and Roasted Chili Corn Salsa' 'Carnitas Soft Tacos'
#  'Chicken Salad' 'Canned Soft Drink' 'Steak Salad Bowl'
#  '6 Pack Soft Drink' 'Chips and Tomatillo-Red Chili Salsa' 'Bowl'
#  'Burrito' 'Crispy Tacos' 'Carnitas Crispy Tacos' 'Steak Salad'
#  'Chips and Mild Fresh Tomato Salsa' 'Veggie Soft Tacos'
# ...

# %% [markdown]
# 4.3 top 5 selling items

# %%
details.groupby("item_name")['quantity'].sum().sort_values(ascending=False).head()
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %% [markdown]
# 4.4 Least 5 selling item

# %%
details.groupby("item_name")["quantity"].sum().sort_values().head()
# Out:
# item_name
# Carnitas Salad                       1
# Veggie Crispy Tacos                  1
# Chips and Mild Fresh Tomato Salsa    1
# Crispy Tacos                         2
# Salad                                2
# Name: quantity, dtype: int64

# %% [markdown]
# DATA CLEANING

# %%
details['item_price'] = details['item_price'].str.replace('$', '').astype(float)

# %%
details.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %% [markdown]
# TASK
# 1) Top 5 selling item with renevue it made
# 2) total revenue of top 5 item
# 3) FInd out 2 more question of same dataset

# %%
details.groupby("item_name")['item_price'].sum().sort_values(ascending=False).head()
# Out:
# item_name
# Chicken Bowl           7342.73
# Chicken Burrito        5575.82
# Steak Burrito          3851.43
# Steak Bowl             2260.19
# Chips and Guacamole    2201.04
# Name: item_price, dtype: float64

# %%
details.assign(revenue=details["quantity"] * details["item_price"]).groupby("item_name")["revenue"].sum().sort_values(ascending=False).head(5)
# Out:
# item_name
# Chicken Bowl           8044.63
# Chicken Burrito        6387.06
# Steak Burrito          4236.13
# Steak Bowl             2479.81
# Chips and Guacamole    2475.62
# Name: revenue, dtype: float64

# %% [markdown]
# Chapter 3 - Pandas Data Structure
# 1D - Series
# 2D - DataFrames

# %%
pd.Series(data=[1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'], name='my_series')
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: my_series, dtype: int64

# %%
pd.DataFrame(data= {"name":["ram", "jam", "sam"], "english":[90, 55, 60], "science":[55, 74, 100]})
# Out:
#   name  english  science
# 0  ram       90       55
# 1  jam       55       74
# 2  sam       60      100

# %% [markdown]
# Chapter 4 - filtering & selecting & sorting

# %% [markdown]
# Chapter 5 - Missing Values

# %% [markdown]
# Step 1 - Check with client and ask wheather they can provide proper data
#
# if not
# step 2 - remove duplicate data
# step 3 - find out null values
# step 4 - drop null records

# %%
data = pd.read_csv("data.tsv.txt", sep = '\t')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)

# %%
data.isnull().sum()
df.dropna() # remove if atleast one column has null
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1228
# item_price               0
# dtype: int64
